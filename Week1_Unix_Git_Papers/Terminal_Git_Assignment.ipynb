# %% [markdown]
# # Intro2Astro Week 1
# ## Unix, the terminal and Git
# by Alejandra Hernández Gómez
# ### Part 1. The terminal

# %% [markdown]
# Assignment 1: Terminal practice
# - Create a new directory named foo_dir
# - Change directories to foo_dir
# - Write "Hello, world" to a text file
# - Display the contents of the text file
# - Make a copy of the text file
# - Place the copy in a new sub-directory, foo_sub_dir
#
# Deliverable: Upload a screenshot of your terminal commands

# %% [markdown]
# Assignment 2: Complete the [Software Carpentry Course for Unix](https://swcarpentry.github.io/shell-novice/)

# %% [markdown]
# ### Part 2. Git and Github

# %% [markdown]
# Assigment 3: Create a GitHub account and read the [Start Your Journey articles](https://docs.github.com/en/get-started/start-your-journey/about-github-and-git) from Github
#
# Remember to keep your name professional, since you might use it for work in the future.
# If you already have an account you don't have to create a new one.

# %% [markdown]
# Assignment 4: Git practice
# - Initialize a repository in the foo_dir directory you created in part 1
# - Add the file where you wrote "Hello, world" and it's copy to the tracked files
# - Make a commit of this files, adding the text "My first commit" to the message
#
# Deliverable: Upload a screenshot of your terminal commands

# %% [markdown]
# Note that assignment 2 and 3 don't have deliverables, this are just for you, but you should still do them to keep learning!
